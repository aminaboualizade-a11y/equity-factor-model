# %%
# Import packages

import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
#Define stock tickers and date range

stocks = ["AAPL", "MSFT", "TSLA"]
start_date = "2024-01-01"
end_date = "2025-12-31"

# %%
# Download stock data from Yahoo Finance

data = yf.download(stocks, start = start_date, end= end_date)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
#Create 'data' folder as it doesn't exist
import os

# Make sure the folder exists
os.makedirs("../data", exist_ok=True)

# %%
# Save stock data to a CSV file in the 'data' folder

data.to_csv("../data/stock_data.csv")

# %%
data_check = pd.read_csv("../data/stock_data.csv", index_col=0)
data_check.head()
# Out:
#                          Close            Close.1             Close.2  \
# Price
# Ticker                    AAPL               MSFT                TSLA
# Date                       NaN                NaN                 NaN
# 2024-01-02  183.90322875976562  365.4216003417969   248.4199981689453
# 2024-01-03  182.52621459960938  365.1556091308594   238.4499969482422
# 2024-01-04  180.20816040039062  362.5346374511719  237.92999267578125
#
#                           High              High.1              High.2  \
# Price
# Ticker                    AAPL                MSFT                TSLA
# Date                       NaN                 NaN                 NaN
# 2024-01-02  186.67703614744315  370.37770417291745              251.25
# 2024-01-03  184.14096966630487   367.7765353087628  245.67999267578125
# 2024-01-04  181.37711375703753   367.6188360826796   242.6999969482422
#
#                            Low               Low.1               Low.2  \
# Price
# Ticker                    AAPL                MSFT                TSLA
# Date                       NaN                 NaN                 NaN
# 2024-01-02  182.16960103197144   361.3818268052928  244.41000366210938
# 2024-01-03   181.7138790075681  363.09631643448915  236.32000732421875
# 2024-01-04   179.1877976853389   361.7759602590735  237.72999572753906
#
#                           Open              Open.1              Open.2  \
# Price
# Ticker                    AAPL                MSFT                TSLA
# Date                       NaN                 NaN                 NaN
# 2024-01-02  185.39909638597572   368.3676650837192   250.0800018310547
# 2024-01-03   182.4964964795135  363.58897105283376  244.97999572753906
# 2024-01-04  180.44590542694291   365.2245421546535              239.25
#
#               Volume  Volume.1   Volume.2
# Price
# Ticker          AAPL      MSFT       TSLA
# Date             NaN       NaN        NaN
# 2024-01-02  82488700  25258600  104654200
# 2024-01-03  58414500  23083500  121082600
# 2024-01-04  71983600  20901500  102629300

# %%
# Check the data columns

data.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close', 'MSFT'),
#             ( 'Close', 'TSLA'),
#             (  'High', 'AAPL'),
#             (  'High', 'MSFT'),
#             (  'High', 'TSLA'),
#             (   'Low', 'AAPL'),
#             (   'Low', 'MSFT'),
#             (   'Low', 'TSLA'),
#             (  'Open', 'AAPL'),
#             (  'Open', 'MSFT'),
#             (  'Open', 'TSLA'),
#             ('Volume', 'AAPL'),
#             ('Volume', 'MSFT'),
#             ('Volume', 'TSLA')],
#            names=['Price', 'Ticker'])

# %%
# Select only the Close prices for all tickers. 
# Handle MultiIndex columns
# For multiple tickers, columns have two levels (e.g., ('Close','AAPL'))
# Select only the Close prices

data_close = data['Close']  # This selects all columns where Level 0 is 'Close'
data_close.head()
# Out:
# Ticker            AAPL        MSFT        TSLA
# Date
# 2024-01-02  183.903229  365.421600  248.419998
# 2024-01-03  182.526215  365.155609  238.449997
# 2024-01-04  180.208160  362.534637  237.929993
# 2024-01-05  179.484940  362.347443  237.490005
# 2024-01-08  183.823959  369.185486  240.449997

# %%
#Plot stock prices

import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

for stock in data_close.columns:
    plt.plot(data_close[stock], label=stock)

plt.title("Stock Prices Over Time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
# Save cleaned Close data to CSV
    
data_close.to_csv("../data/stock_close.csv")
